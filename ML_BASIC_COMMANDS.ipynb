# %% [markdown]
# <a href="https://colab.research.google.com/github/EniyanCSE/Ai_Project/blob/main/ML_BASIC_COMMANDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = [['apple',10,240],['orange',15,150],['grapes',14,80],['pineapple',10,70]]

df1 = pd.DataFrame(data, columns = ['Fruit_Name','Quantity','Unit_Price'])

df1
# Out:
#   Fruit_Name  Quantity  Unit_Price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70

# %%
df1.shape

# %%
df1.info
# Out:
# <bound method DataFrame.info of   Fruit_Name  Quantity  Unit_Price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70>

# %%
df1.describe()
# Out:
#         Quantity  Unit_Price
# count   4.000000    4.000000
# mean   12.250000  135.000000
# std     2.629956   78.528127
# min    10.000000   70.000000
# 25%    10.000000   77.500000
# 50%    12.000000  115.000000
# 75%    14.250000  172.500000
# max    15.000000  240.000000

# %%
df1.plot()
# Out:
# <Axes: >
